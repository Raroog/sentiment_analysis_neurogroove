# %%
import pandas as pd

# %%
df = pd.read_csv("/home/bartek/PycharmProjects/sentiment_analysis_neurogroove/Trip_reports.csv")

# %%
df.head()
# Out:
#    Substancja wiodąca                               Natura   Chemia  \
# 0          Marihuana                            Marihuana      brak
# 1            Kodeina                                  brak     brak
# 2               Eter                                  brak    Eter
# 3            Morfina                                  brak     brak
# 4          Marihuana     Marihuana (godfather og 21% thc)      brak
#
#                      Apteka                              Dawkowanie  \
# 0                      brak                              2/3 lufy
# 1    Kodeina, Hydroksyzyna     300 mg kodeiny + 10 mg hydroksyzyny
# 2                      brak                                    ...
# 3                  Morfina                                     ...
# 4                      brak                                 1 tłok
#
#          Rodzaj przeżycia                                        Set&Setting  \
# ...
